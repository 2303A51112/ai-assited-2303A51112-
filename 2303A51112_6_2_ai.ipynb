# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51112/ai-assited-2303A51112-/blob/main/2303A51112_6_2_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Classes – Data Validation

# %%
class Student:
    def __init__(self, name, roll_no, marks):
        self.name = name
        self.roll_no = roll_no
        self.marks = marks

    def is_pass(self):
        if self.marks >= 40:
            return "Pass"
        else:
            return "Fail"

# %% [markdown]
# Task 2: Loops – Pattern Generation

# %%
def pattern_while(n):
    i = 1
    while i <= n:
        print("*" * i)
        i += 1

# %% [markdown]
# Task 3: Conditional Statements – Number Analysis

# %%
def analyze_number(num):
    if num > 0:
        return "Positive"
    elif num < 0:
        return "Negative"
    else:
        return "Zero"

# %% [markdown]
# Task 4: Nested Conditionals – Discount Eligibility

# %%
def check_discount(age, is_member):
    if age >= 60:
        if is_member:
            return "Senior + Member Discount"
        else:
            return "Senior Discount"
    else:
        if is_member:
            return "Member Discount"
        else:
            return "No Discount"

# %% [markdown]
# Task 5: Class – Mathematical Operations (Circle)

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius * self.radius

    def circumference(self):
        return 2 * math.pi * self.radius
