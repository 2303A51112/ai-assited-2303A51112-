# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51112/ai-assited-2303A51112-/blob/main/2303A51112_3_2_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Task 1: Progressive Prompting for Calculator Design

# %%
def calculator(a, b, operation):
    if operation == "add":
        return a + b
    elif operation == "sub":
        return a - b
    elif operation == "mul":
        return a * b
    elif operation == "div":
        if b != 0:
            return a / b
        return "Division by zero not allowed"

# %% [markdown]
# Task 2: Refining Prompts for Sorting Logic

# %%
def sort_marks_desc(marks):
    return sorted(marks, reverse=True)

# %% [markdown]
# Task 3: Few-Shot Prompting for Prime Number Validation

# %%
m1 = int(input("Enter marks 1: "))
m2 = int(input("Enter marks 2: "))
m3 = int(input("Enter marks 3: "))

total = m1 + m2 + m3
percentage = total / 3

if percentage >= 75:
    grade = "A"
elif percentage >= 60:
    grade = "B"
elif percentage >= 40:
    grade = "C"
else:
    grade = "Fail"

print("Total:", total)
print("Percentage:", percentage)
print("Grade:", grade)
# Out:
# Enter marks 1: 1
# Enter marks 2: 2
# Enter marks 3: 3
# Total: 6
# Percentage: 2.0
# Grade: Fail

# %% [markdown]
# Task 5: Analyzing Prompt Specificity in Unit Conversion Function

# %%
def convert_distance(value, unit):
    if unit == "km_to_miles":
        return value * 0.621371
    elif unit == "miles_to_km":
        return value / 0.621371
